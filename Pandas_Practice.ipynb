# %%
import pandas as pd

# %%
#Q1
pop = pd.read_csv(r"C:\Users\Swapnil\.vscode\Assignments\population_by_county.csv")

# %%
#Q2
pop.head()
pop.head(8)
# Out:
#              County           State  2010Census  2017PopEstimate
# 0  Abbeville County  South Carolina       25417            24722
# 1     Acadia Parish       Louisiana       61773            62590
# 2   Accomack County        Virginia       33164            32545
# 3        Ada County           Idaho      392365           456849
# 4      Adair County            Iowa        7682             7054
# 5      Adair County        Kentucky       18656            19485
# 6      Adair County        Missouri       25607            25377
# 7      Adair County        Oklahoma       22683            21909

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3142 entries, 0 to 3141
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   County           3142 non-null   object
#  1   State            3142 non-null   object
#  2   2010Census       3142 non-null   int64
#  3   2017PopEstimate  3142 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 98.3+ KB

# %%
#Q3
pop.columns
# Out:
# Index(['County', 'State', '2010Census', '2017PopEstimate'], dtype='object')

# %%
#Q4
pop["State"]
# Out:
# 0       South Carolina
# 1            Louisiana
# 2             Virginia
# 3                Idaho
# 4                 Iowa
#              ...
# 3137           Arizona
# 3138          Colorado
# 3139             Texas
# 3140             Texas
# 3141      South Dakota
# Name: State, Length: 3142, dtype: object

# %%
#Q4
len(pop["State"])
# Out:
# 3142

# %%
#Q5
pop["State"].tolist()
# Out:
# ['South Carolina',
#  'Louisiana',
#  'Virginia',
#  'Idaho',
#  'Iowa',
#  'Kentucky',
#  'Missouri',
#  'Oklahoma',
#  'Colorado',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Mississippi',
#  'Nebraska',
#  'North Dakota',
#  'Ohio',
#  'Pennsylvania',
#  'Washington',
#  'Wisconsin',
#  'Vermont',
#  'South Carolina',
#  'Minnesota',
#  'Florida',
#  'North Carolina',
#  'California',
#  'Colorado',
#  'New York',
#  'Wyoming',
#  'Virginia',
#  'Michigan',
#  'Mississippi',
#  'Alaska',
#  'Alaska',
#  'Illinois',
#  'North Carolina',
#  'Virginia',
#  'Oklahoma',
#  'Michigan',
#  'Iowa',
#  'Michigan',
#  'Maryland',
#  'New York',
#  'North Carolina',
#  'Virginia',
#  'Pennsylvania',
#  'Indiana',
#  'Kansas',
#  'Kentucky',
#  'Ohio',
#  'Louisiana',
#  'South Carolina',
#  'Michigan',
#  'California',
#  'California',
#  'Virginia',
#  'Virginia',
#  'Mississippi',
#  'Alaska',
#  'Kansas',
#  'Kentucky',
#  'South Carolina',
#  'Tennessee',
#  'Texas',
# ...

# %%
#Q6
pop["County"].value_counts().head(5)
# Out:
# County
# Washington County    30
# Jefferson County     25
# Franklin County      24
# Jackson County       23
# Lincoln County       23
# Name: count, dtype: int64

# %%
#Q7
pop.sort_values(by="2010Census", ascending=False).head(5)["County"].tolist()
# Out:
# ['Los Angeles County',
#  'Cook County',
#  'Harris County',
#  'Maricopa County',
#  'San Diego County']

# %%
#Q8
pop.sort_values(by="2010Census", ascending=False).head(5)["State"].tolist()
# Out:
# ['California', 'Illinois', 'Texas', 'Arizona', 'California']

# %%
#Q9
(pop["2010Census"]>1000000).sum()
# Out:
# np.int64(39)

# %%
#Q10
(~pop["County"].str.contains("County", na=False)).sum()
# Out:
# np.int64(135)

# %%
#Q11
pop["Percentage_Pop_Change_2010_to_2017"]=((pop["2017PopEstimate"]-pop["2010Census"])/pop["2010Census"])*100

# %%
pop.head()
# Out:
#              County           State  2010Census  2017PopEstimate  \
# 0  Abbeville County  South Carolina       25417            24722
# 1     Acadia Parish       Louisiana       61773            62590
# 2   Accomack County        Virginia       33164            32545
# 3        Ada County           Idaho      392365           456849
# 4      Adair County            Iowa        7682             7054
#
#    Percentage_Pop_Change_2010_to_2017
# 0                           -2.734390
# 1                            1.322584
# 2                           -1.866482
# 3                           16.434697
# 4                           -8.174954

# %%
#Q12
state_pop=pop.groupby("State")[["2010Census", "2017PopEstimate"]].sum()
state_pop["Percentage_Pop_Change_2010_to_2017"]=((state_pop["2017PopEstimate"]-state_pop["2010Census"])/state_pop["2010Census"])*100
state_pop.sort_values(by="Percentage_Pop_Change_2010_to_2017", ascending=False).head().index.to_list()
# Out:
# ['District of Columbia', 'Texas', 'North Dakota', 'Utah', 'Florida']
